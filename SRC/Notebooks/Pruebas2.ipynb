# %%
import pandas as pd

# %%
df_2018 = pd.read_csv('/Users/valdecantos/Documents/The_Bridge/Alumno_Folder/Alumno_Curso/datascience_thebridge_9_21/2-Data_analysis/entregas/EDA/Data/top2018.csv')
df_2018.head()
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %%
df_2020 = pd.read_csv('/Users/valdecantos/Documents/The_Bridge/Alumno_Folder/Alumno_Curso/datascience_thebridge_9_21/2-Data_analysis/entregas/EDA/Data/top2020.csv')
df_2020.head()
# Out:
#    Unnamed: 0       artist                                  album  \
# 0           0   The Weeknd                            After Hours
# 1           1  Tones And I                           Dance Monkey
# 2           2  Roddy Ricch  Please Excuse Me For Being Antisocial
# 3           3    SAINt JHN                  Roses (Imanbek Remix)
# 4           4     Dua Lipa                       Future Nostalgia
#
#               track_name                track_id  energy  danceability  key  \
# 0        Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b   0.730         0.514    1
# 1           Dance Monkey  1rgnBhdG2JDFTbYkYRZAku   0.593         0.825    6
# 2                The Box  0nbXyq5TXYPCO7pr3N8S4I   0.586         0.896   10
# 3  Roses - Imanbek Remix  2Wo6QQD1KMDWeFkkjLqwx5   0.721         0.785    8
# 4        Don't Start Now  3PfIrDoz19wz7qK7tYeu62   0.793         0.793   11
#
#    loudness  acousticness  speechiness  instrumentalness  liveness  valence  \
# ...

# %%
generos = df_2020.groupby(['artist', 'genre']).count()
generos
# Out:
#                                                     Unnamed: 0  album  \
# artist          genre
# 24kGoldn        Pop rap                                      1      1
# Ariana Grande   Pop                                          1      1
# Arizona Zervas  Hip-Hop/Rap                                  1      1
# BENEE           Alternative/Indie                            1      1
# BTS             Disco-pop                                    1      1
# Bad Bunny       Alternative/reggaeton/experimental           1      1
# Billie Eilish    Electro-pop                                 1      1
#                 Chamber pop                                  1      1
#                 Pop                                          1      1
# Black Eyed Peas Pop                                          1      1
# Cardi B         Hip-Hop/Trap                                 1      1
# DaBaby          Hip-Hop/Rap                                  1      1
# ...

# %%
generos2 = df_2020['genre'].value_counts()
generos2

# lo divido en dos df1 = df.iloc[0:5] y df2 = df.iloc[6:]  después sum = df2[sum] y por último df1.append
# Out:
# Pop                                   14
# Hip-Hop/Rap                           13
# Dance/Electronic                       5
# Alternative/Indie                      4
# R&B/Soul                               2
#  Electro-pop                           2
# Nu-disco                               1
# R&B/Hip-Hop alternative                1
# Pop/Soft Rock                          1
# Pop rap                                1
# Hip-Hop/Trap                           1
# Dance-pop/Disco                        1
# Disco-pop                              1
# Dreampop/Hip-Hop/R&B                   1
# Alternative/reggaeton/experimental     1
# Chamber pop                            1
# Name: genre, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
my_circle=plt.Circle( (0,0), 0.7, color='white')

plt.figure(figsize=(8,8))

plt.pie(generos2.values,
        labels = generos2.index,
        autopct='%1.2f%%')

p = plt.gcf() # hacer referencia a la figura "activa"
p.gca().add_artist(my_circle) ;# gca haría referencia al axes "activo"

# %%
artista = df_2020['artist'].value_counts()
artista.head(10)
# Out:
# Billie Eilish    3
# Dua Lipa         3
# Travis Scott     3
# Justin Bieber    2
# Harry Styles     2
# Lewis Capaldi    2
# Post Malone      2
# Cardi B          1
# Surfaces         1
# Eminem           1
# Name: artist, dtype: int64

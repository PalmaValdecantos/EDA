# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Mostramos el DataSet original de 2018

# %%
df_2018 = pd.read_csv('/Users/valdecantos/Documents/The_Bridge/Alumno_Folder/Alumno_Curso/datascience_thebridge_9_21/2-Data_analysis/entregas/EDA/Data/top2018.csv')
df_2018.head()
# Out:
#                       id                          name       artists  \
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.754   0.449  7.0    -9.211   1.0       0.1090        0.0332
# 1         0.740   0.613  8.0    -4.880   1.0       0.1450        0.2580
# 2         0.587   0.535  5.0    -6.090   0.0       0.0898        0.1170
# 3         0.739   0.559  8.0    -8.011   1.0       0.1170        0.5800
# 4         0.835   0.626  1.0    -5.833   1.0       0.1250        0.0589
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature
# ...

# %% [markdown]
# Eliminamos filas y columnas del DataFrame de 2018

# %%
df_2018_Top50 = df_2018.drop(range(50, 100), axis=0)
df_2018_limpio = df_2018_Top50.drop(['id', 'key', 'instrumentalness', 'mode', 'time_signature'], axis=1)
df_2018_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          50 non-null     object
#  1   artists       50 non-null     object
#  2   danceability  50 non-null     float64
#  3   energy        50 non-null     float64
#  4   loudness      50 non-null     float64
#  5   speechiness   50 non-null     float64
#  6   acousticness  50 non-null     float64
#  7   liveness      50 non-null     float64
#  8   valence       50 non-null     float64
#  9   tempo         50 non-null     float64
#  10  duration_ms   50 non-null     float64
# dtypes: float64(9), object(2)
# memory usage: 4.7+ KB

# %% [markdown]
# Mostramos el Dataset Original de 2019

# %%
df_2019 = pd.read_csv('/Users/valdecantos/Documents/The_Bridge/Alumno_Folder/Alumno_Curso/datascience_thebridge_9_21/2-Data_analysis/entregas/EDA/Data/top2019.csv', encoding= 'latin1')
df_2019.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
df_2019_limpio = df_2019.drop(['Unnamed: 0', 'Popularity'], axis=1)
df_2019_limpio.rename(columns={'Track.Name' : 'name', 'Artist.Name' : 'artist', 'Genre' : 'genre', 'Beats.Per.Minute': 'tempo', 'Energy' : 'energy', 'Danceability' : 'danceability', 'Loudness..dB..' : 'loudness', 'Liveness' : 'liveness', 'Valence.' : 'valence', 'Length.' : 'duration_ms', 'Acousticness..' : 'acousticness', 'Speechiness.' : 'speechiness'}, inplace=True)
df_2019_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          50 non-null     object
#  1   artist        50 non-null     object
#  2   genre         50 non-null     object
#  3   tempo         50 non-null     int64
#  4   energy        50 non-null     int64
#  5   danceability  50 non-null     int64
#  6   loudness      50 non-null     int64
#  7   liveness      50 non-null     int64
#  8   valence       50 non-null     int64
#  9   duration_ms   50 non-null     int64
#  10  acousticness  50 non-null     int64
#  11  speechiness   50 non-null     int64
# dtypes: int64(9), object(3)
# memory usage: 4.8+ KB

# %%
df_2019_limpio['energy'].astype('str').dtypes
#df[['second', 'third']].astype(float)
#df.astype('int32').dtypes
# Out:
# dtype('O')

# %%
[df_2019_limpio_f] = [df_2019_limpio]['tempo', 'energy', 'danceability', 'loudness', 'liveness', 'valence', 'duration_ms', 'acousticness', 'speechiness'].astype('float64')
df_2019_limpio.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/vw/xsl3jt6s4vsgf01j03rl_vkm0000gn/T/ipykernel_7821/4166767537.py in <module>
# ----> 1 [df_2019_limpio_f] = [df_2019_limpio]['tempo', 'energy', 'danceability', 'loudness', 'liveness', 'valence', 'duration_ms', 'acousticness', 'speechiness'].astype('float64')
#       2 df_2019_limpio.info()
#
# TypeError: list indices must be integers or slices, not tuple

# %%
df_2019_limpio_f.head()
# Out:
#    tempo  energy  danceability  loudness  liveness  valence  duration_ms  \
# 0  117.0    55.0          76.0      -6.0       8.0     75.0        191.0
# 1  105.0    81.0          79.0      -4.0       8.0     61.0        302.0
# 2  190.0    80.0          40.0      -4.0      16.0     70.0        186.0
# 3   93.0    65.0          64.0      -8.0       8.0     55.0        198.0
# 4  150.0    65.0          58.0      -4.0      11.0     18.0        175.0
#
#    acousticness  speechiness
# 0           4.0          3.0
# 1           8.0          9.0
# 2          12.0         46.0
# 3          12.0         19.0
# 4          45.0          7.0

# %% [markdown]
# Mostramos el DataSet original de 2020

# %%
df_2020 = pd.read_csv('spotifytoptracks.csv')
df_2020.head()
# Out:
#    Unnamed: 0       artist                                  album  \
# 0           0   The Weeknd                            After Hours
# 1           1  Tones And I                           Dance Monkey
# 2           2  Roddy Ricch  Please Excuse Me For Being Antisocial
# 3           3    SAINt JHN                  Roses (Imanbek Remix)
# 4           4     Dua Lipa                       Future Nostalgia
#
#               track_name                track_id  energy  danceability  key  \
# 0        Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b   0.730         0.514    1
# 1           Dance Monkey  1rgnBhdG2JDFTbYkYRZAku   0.593         0.825    6
# 2                The Box  0nbXyq5TXYPCO7pr3N8S4I   0.586         0.896   10
# 3  Roses - Imanbek Remix  2Wo6QQD1KMDWeFkkjLqwx5   0.721         0.785    8
# 4        Don't Start Now  3PfIrDoz19wz7qK7tYeu62   0.793         0.793   11
#
#    loudness  acousticness  speechiness  instrumentalness  liveness  valence  \
# ...

# %%
df_2020_limpio = df_2020.drop(['Unnamed: 0', 'album', 'track_id', 'key', 'instrumentalness',], axis=1)
df_2020_limpio.rename(columns={'track_name' : 'name'}, inplace=True)
df_2020_limpio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist        50 non-null     object
#  1   name          50 non-null     object
#  2   energy        50 non-null     float64
#  3   danceability  50 non-null     float64
#  4   loudness      50 non-null     float64
#  5   acousticness  50 non-null     float64
#  6   speechiness   50 non-null     float64
#  7   liveness      50 non-null     float64
#  8   valence       50 non-null     float64
#  9   tempo         50 non-null     float64
#  10  duration_ms   50 non-null     int64
#  11  genre         50 non-null     object
# dtypes: float64(8), int64(1), object(3)
# memory usage: 4.8+ KB

# %%
df_2020_limpio.head()
# Out:
#         artist                   name  energy  danceability  loudness  \
# 0   The Weeknd        Blinding Lights   0.730         0.514    -5.934
# 1  Tones And I           Dance Monkey   0.593         0.825    -6.401
# 2  Roddy Ricch                The Box   0.586         0.896    -6.687
# 3    SAINt JHN  Roses - Imanbek Remix   0.721         0.785    -5.457
# 4     Dua Lipa        Don't Start Now   0.793         0.793    -4.521
#
#    acousticness  speechiness  liveness  valence    tempo  duration_ms  \
# 0       0.00146       0.0598    0.0897    0.334  171.005       200040
# 1       0.68800       0.0988    0.1700    0.540   98.078       209755
# 2       0.10400       0.0559    0.7900    0.642  116.971       196653
# 3       0.01490       0.0506    0.2850    0.894  121.962       176219
# 4       0.01230       0.0830    0.0951    0.679  123.950       183290
#
#                genre
# 0           R&B/Soul
# 1  Alternative/Indie
# 2        Hip-Hop/Rap
# 3   Dance/Electronic
# ...

# %%
df_2018_limpio.head()
# Out:
#                            name       artists  danceability  energy  loudness  \
# 0                    God's Plan         Drake         0.754   0.449    -9.211
# 1                          SAD!  XXXTENTACION         0.740   0.613    -4.880
# 2    rockstar (feat. 21 Savage)   Post Malone         0.587   0.535    -6.090
# 3  Psycho (feat. Ty Dolla $ign)   Post Malone         0.739   0.559    -8.011
# 4                In My Feelings         Drake         0.835   0.626    -5.833
#
#    speechiness  acousticness  liveness  valence    tempo  duration_ms
# 0       0.1090        0.0332     0.552    0.357   77.169     198973.0
# 1       0.1450        0.2580     0.123    0.473   75.023     166606.0
# 2       0.0898        0.1170     0.131    0.140  159.847     218147.0
# 3       0.1170        0.5800     0.112    0.439  140.124     221440.0
# 4       0.1250        0.0589     0.396    0.350   91.030     217925.0

# %% [markdown]
# -	¿Qué genero es el más bailable de media? ¿pertenece la canción más bailable (con mejor índice danceability) a dicho género?

# %%
df_2020_limpio[['genre','danceability']]
# Out:
#                                  genre  danceability
# 0                             R&B/Soul         0.514
# 1                    Alternative/Indie         0.825
# 2                          Hip-Hop/Rap         0.896
# 3                     Dance/Electronic         0.785
# 4                             Nu-disco         0.793
# 5                          Hip-Hop/Rap         0.746
# 6                                  Pop         0.548
# 7                          Hip-Hop/Rap         0.726
# 8              R&B/Hip-Hop alternative         0.784
# 9                    Alternative/Indie         0.501
# 10                                 Pop         0.803
# 11                         Hip-Hop/Rap         0.621
# 12                       Pop/Soft Rock         0.695
# 13                         Hip-Hop/Rap         0.774
# 14                                 Pop         0.806
# 15                         Hip-Hop/Rap         0.830
# 16                   Alternative/Indie         0.459
# ...

# %%
genero_bailable = df_2020_limpio[['genre','danceability']].groupby(["genre"]).mean().sort_values(by=['danceability'], ascending=False)
genero_bailable
# Out:
#                                     danceability
# genre
# Hip-Hop/Trap                            0.935000
# Nu-disco                                0.793000
#  Electro-pop                            0.789500
# R&B/Hip-Hop alternative                 0.784000
# Hip-Hop/Rap                             0.765538
# Dance/Electronic                        0.755000
# Dreampop/Hip-Hop/R&B                    0.755000
# Disco-pop                               0.746000
# Dance-pop/Disco                         0.730000
# Pop rap                                 0.700000
# Pop/Soft Rock                           0.695000
# Pop                                     0.677571
# Alternative/Indie                       0.661750
# R&B/Soul                                0.650500
# Alternative/reggaeton/experimental      0.607000
# Chamber pop                             0.351000

# %%
cancion_bailable = df_2020_limpio[['name', 'genre','danceability']].max()
cancion_bailable
# Out:
# name            lovely (with Khalid)
# genre                       R&B/Soul
# danceability                   0.935
# dtype: object

# %% [markdown]
# -	¿Si quieres tener éxito en las pistas de baile qué atributos debe tener la canción?  variable =  df.corr()  que tipo es? Y coger la columna bailable.

# %%
atributos_bailabilidad_2018 = df_2018_limpio.corr()
atributos_bailabilidad_2018.iloc[:, 0]
# Out:
# danceability    1.000000
# energy         -0.169779
# loudness        0.059825
# speechiness     0.096603
# acousticness    0.109359
# liveness       -0.063121
# valence         0.409725
# tempo          -0.085296
# duration_ms     0.152614
# Name: danceability, dtype: float64

# %%
atributos_bailabilidad_2020 = df_2020_limpio.corr()
atributos_bailabilidad_2020.iloc[:, 1]
# Out:
# energy          0.152552
# danceability    1.000000
# loudness        0.167147
# acousticness   -0.359135
# speechiness     0.226148
# liveness       -0.006648
# valence         0.479953
# tempo           0.168956
# duration_ms    -0.033763
# Name: danceability, dtype: float64

# %%
def columna_año(pasar_año):
    año = []
    columna =pd.Series(np.arange(1,51))
    for i in columna:
        año.append(pasar_año)
    return año
columna_año(2020)
# Out:
# [2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020,
#  2020]

# %%
columna =pd.Series(np.arange(1,51,))
año = []
for i in columna:
    año.append(2018)
año
# Out:
# [2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018,
#  2018]

# %%
date = []
def columna_date(pasar_date):
    
    columna =pd.Series(np.arange(1,51))
    for i in columna:
        date.append(pasar_date)
    return date
columna_date(2019)

pd.DataFrame(data=date, columns=['date'])
#pd_date = pd.concat([df_2019_limpio, date], axis=0)
#df_2019_limpio['date'] = date
#df_2019_limpio
#pd_date
# Out:
#     date
# 0   2019
# 1   2019
# 2   2019
# 3   2019
# 4   2019
# 5   2019
# 6   2019
# 7   2019
# 8   2019
# 9   2019
# 10  2019
# 11  2019
# 12  2019
# 13  2019
# 14  2019
# 15  2019
# 16  2019
# 17  2019
# 18  2019
# 19  2019
# 20  2019
# 21  2019
# 22  2019
# 23  2019
# 24  2019
# 25  2019
# 26  2019
# 27  2019
# 28  2019
# 29  2019
# 30  2019
# 31  2019
# 32  2019
# 33  2019
# 34  2019
# 35  2019
# 36  2019
# 37  2019
# 38  2019
# 39  2019
# 40  2019
# 41  2019
# 42  2019
# 43  2019
# 44  2019
# 45  2019
# 46  2019
# 47  2019
# 48  2019
# 49  2019

# %%
pd.DataFrame(np.random.rand(3, 2),
             columns=['foo', 'bar'],
             index=['a', 'b', 'c'])
# Out:
#         foo       bar
# a  0.250872  0.074260
# b  0.556326  0.104007
# c  0.015070  0.372029

# %%
pd.DataFrame(3, 2),
             columns=['foo', 'bar'],
             index=['a', 'b', 'c'])

# %%
pip install pyqt5
# Out:
# ...
#     100% |████████████████████████████████| 7.0MB 4.2MB/s
# ...
#     100% |████████████████████████████████| 71kB 13.9MB/s
# ...
#     100% |████████████████████████████████| 40.6MB 793kB/s
# ...
# You are using pip version 19.0.3, however version 21.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
top_generos_2020 = pd.DataFrame(data=top_generos_2020, columns=['genre'])
#QQ =top_generos_2020.groupby(['genre'], as_index = False).mean()
#QQ
#Nueva_df =top_generos_2020.reset_index()
#Nueva_df
top_generos_2020.reset_index()
#top_generos_2020.rename(columns={'index' : 'genero', 'genre' : 'recuento'}, inplace=True)
#top_generos_2020
